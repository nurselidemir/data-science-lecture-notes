# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numpyDizisi1 = np.linspace(0,10,20)

# %%
numpyDizisi1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyDizisi2 = numpyDizisi1 ** 2

# %%
numpyDizisi2
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
(benimFigure, benimEksen) = pyt.subplots()

benimEksen.plot(numpyDizisi1, numpyDizisi2, color = "#003399")
benimEksen.plot(numpyDizisi2, numpyDizisi1, color = "#990000")
plt.show()

# %%
(yeniFigure, yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 2, color = "blue", linewidth = 5.0)
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 5, color = "purple", linestyle = ":")
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 8, color = "green", linestyle = "--", marker = "o", markersize = 10, markerfacecolor = "red")
plt.show()

# %% [markdown]
# ## scatter

# %%
plt.scatter(numpyDizisi1, numpyDizisi2)
plt.show()

# %% [markdown]
# ## histogram

# %%
yeniDizi = np.random.randint(0,100,50)

# %%
yeniDizi
# Out:
# array([32, 88, 10, 68, 98, 45, 75, 69, 21, 58, 82, 80, 56, 25, 95, 29, 69,
#        96, 53, 43, 11, 94, 68, 40,  3, 33, 12, 73, 30, 72, 76, 52,  7, 90,
#        97, 27, 70, 90, 15, 13, 96, 67, 75, 74, 50, 72, 26, 54, 55,  9])

# %%
plt.hist(yeniDizi)
plt.show()

# %% [markdown]
# ## boxplot

# %%
plt.boxplot(yeniDizi)
plt.show()

# %% [markdown]
# standart sapma vs görebilmek için
